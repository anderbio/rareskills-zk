// %%
:dep gf256 = "0.3"

extern crate gf256;
use gf256::GF256
// Out:
// [E0432] Error: unresolved import `gf256::GF256`

// %%
let a: gf256 = gf256(0xfd);
// let b = gf256(0xfe);
// let c = gf256(0xff);
// assert_eq!(a*(b+c), a*b + a*c);
// Out:
// [E0573] Error: expected type, found crate `gf256`
//    ╭─[command_21:1:1]
//    │
//  1 │ let a: gf256 = gf256(0xfd);
//    │        ──┬──
//    │          ╰──── not a type
// ───╯
// Error: consider importing one of these structs instead
